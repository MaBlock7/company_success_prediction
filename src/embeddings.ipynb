# %%
import json
import torch
import torch.nn.functional as F
from torch import Tensor
from langchain_text_splitters import MarkdownHeaderTextSplitter, RecursiveCharacterTextSplitter
from transformers import AutoTokenizer, AutoModel

from config import RAW_DATA_DIR, PROCESSED_DATA_DIR

# %%
uid = 'CHE152876230'
with open(RAW_DATA_DIR / f'{uid}.json') as f:
    data = [content['markdown'] for url, content in json.load(f)[uid].items()]

# %%
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]
markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on, strip_headers=False)
recursive_splitter = RecursiveCharacterTextSplitter(chunk_size=512, chunk_overlap=24)

chunks = []
for markdown in data:
    md_header_splits = markdown_splitter.split_text(markdown)
    chunks.extend(recursive_splitter.split_documents(md_header_splits))

# %%
chunks
# Out:
# [Document(metadata={}, page_content='[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/</>)[Über uns](https://www.chiron-services.ch/</ueber-uns>)[Services](https://www.chiron-services.ch/</services>)[Produkte](https://www.chiron-services.ch/</produkte>)[NEWS](https://www.chiron-services.ch/</news>)\n[DE](https://www.chiron-services.ch/</>)[|](https://www.chiron-services.ch/<#>)[EN](https://www.chiron-services.ch/</en/home>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data'}, page_content='# Unlocking the Value of Data\n[Services](https://www.chiron-services.ch/</services>)[Produkte](https://www.chiron-services.ch/</produkte>)\n![Lock](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435383994b6c658b6bd27d9_chiron_lock_open2%201.webp)\nDigital solutions by digital natives'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Beratung und Entwicklung für Daten, Software und KI Lösungen'}, page_content='## Beratung und Entwicklung für Daten, Software und KI Lösungen\nAls Data Science und Software Unternehmen bieten wir umfassende Beratungs- und Entwicklungsdienstleistungen an, die darauf abzielen, Ihnen einen echten Mehrwert zu bieten. Wir setzen auf innovative Datenlösungen und Softwareentwicklung, um Ihre Anforderungen zu erfüllen. Dafür evaluieren wir jeweils zuerst den Return on Investment, der durch den Einsatz von digitalen Lösungen entsteht.\n[Über uns](https://www.chiron-services.ch/</ueber-uns>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': '[DatenerhebungAutomatisches Sammeln von Daten![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)### [DatenextraktionUmwandlung von unstrukturierten Daten in strukturierte![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)### [DatenmanagementSpeichern und Zugriff auf Daten![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</en/services/data-management>)### [DatenaufbereitungStandardisierung und Organisieren![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)### [KI BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)### [DatenanalyseErkennen von Muster, Beziehungen und Prognosen![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)### [Prozess-automatisierungReduktion manueller Arbeit![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)### [SoftwareentwicklungDigitale Lösungen nach Mass![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)'}, page_content='## Unsere Kernkompetenzen'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': '[DatenerhebungAutomatisches Sammeln von Daten![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)### [DatenextraktionUmwandlung von unstrukturierten Daten in strukturierte![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)### [DatenmanagementSpeichern und Zugriff auf Daten![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</en/services/data-management>)### [DatenaufbereitungStandardisierung und Organisieren![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)### [KI BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)### [DatenanalyseErkennen von Muster, Beziehungen und Prognosen![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)### [Prozess-automatisierungReduktion manueller Arbeit![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)### [SoftwareentwicklungDigitale Lösungen nach Mass![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)'}, page_content='### [DatenerhebungAutomatisches Sammeln von Daten![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)### [DatenextraktionUmwandlung von unstrukturierten Daten in'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': '[DatenerhebungAutomatisches Sammeln von Daten![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)### [DatenextraktionUmwandlung von unstrukturierten Daten in strukturierte![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)### [DatenmanagementSpeichern und Zugriff auf Daten![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</en/services/data-management>)### [DatenaufbereitungStandardisierung und Organisieren![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)### [KI BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)### [DatenanalyseErkennen von Muster, Beziehungen und Prognosen![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)### [Prozess-automatisierungReduktion manueller Arbeit![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)### [SoftwareentwicklungDigitale Lösungen nach Mass![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)'}, page_content='Daten in strukturierte![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)### [DatenmanagementSpeichern und Zugriff auf Daten![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</en/services/data-management>)###'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': '[DatenerhebungAutomatisches Sammeln von Daten![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)### [DatenextraktionUmwandlung von unstrukturierten Daten in strukturierte![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)### [DatenmanagementSpeichern und Zugriff auf Daten![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</en/services/data-management>)### [DatenaufbereitungStandardisierung und Organisieren![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)### [KI BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)### [DatenanalyseErkennen von Muster, Beziehungen und Prognosen![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)### [Prozess-automatisierungReduktion manueller Arbeit![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)### [SoftwareentwicklungDigitale Lösungen nach Mass![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)'}, page_content='[DatenaufbereitungStandardisierung und Organisieren![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)### [KI BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen![KI'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': '[DatenerhebungAutomatisches Sammeln von Daten![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)### [DatenextraktionUmwandlung von unstrukturierten Daten in strukturierte![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)### [DatenmanagementSpeichern und Zugriff auf Daten![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</en/services/data-management>)### [DatenaufbereitungStandardisierung und Organisieren![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)### [KI BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)### [DatenanalyseErkennen von Muster, Beziehungen und Prognosen![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)### [Prozess-automatisierungReduktion manueller Arbeit![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)### [SoftwareentwicklungDigitale Lösungen nach Mass![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)'}, page_content='für Ihr Unternehmen![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)### [DatenanalyseErkennen von Muster, Beziehungen und Prognosen![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)###'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': '[DatenerhebungAutomatisches Sammeln von Daten![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)### [DatenextraktionUmwandlung von unstrukturierten Daten in strukturierte![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)### [DatenmanagementSpeichern und Zugriff auf Daten![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</en/services/data-management>)### [DatenaufbereitungStandardisierung und Organisieren![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)### [KI BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)### [DatenanalyseErkennen von Muster, Beziehungen und Prognosen![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)### [Prozess-automatisierungReduktion manueller Arbeit![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)### [SoftwareentwicklungDigitale Lösungen nach Mass![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)'}, page_content='[Prozess-automatisierungReduktion manueller Arbeit![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)### [SoftwareentwicklungDigitale Lösungen nach'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': '[DatenerhebungAutomatisches Sammeln von Daten![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)### [DatenextraktionUmwandlung von unstrukturierten Daten in strukturierte![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)### [DatenmanagementSpeichern und Zugriff auf Daten![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</en/services/data-management>)### [DatenaufbereitungStandardisierung und Organisieren![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)### [KI BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)### [DatenanalyseErkennen von Muster, Beziehungen und Prognosen![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)### [Prozess-automatisierungReduktion manueller Arbeit![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)### [SoftwareentwicklungDigitale Lösungen nach Mass![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)'}, page_content='Lösungen nach Mass![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': 'Datenerhebung'}, page_content='### Datenerhebung\nAutomatisches Sammeln von Daten\n[![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)](https://www.chiron-services.ch/</services/datenerhebung>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': 'Datenextraktion'}, page_content='### Datenextraktion\nUmwandlung von unstrukturierten Daten in strukturierte\n[![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)](https://www.chiron-services.ch/</services/datenextraktion>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': 'Daten-management'}, page_content='### Daten-management\nSpeicherung und Zugriff auf Daten\n[![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)](https://www.chiron-services.ch/</services/datenmanagement>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': 'Daten-aufbereitung'}, page_content='### Daten-aufbereitung\nStandardisierung und Organisation\n[![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)](https://www.chiron-services.ch/</services/datenaufbereitung>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': 'KI Beratung'}, page_content='### KI Beratung\nEinsatz künstlicher Intelligenz für Ihr Unternehmen\n[![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)](https://www.chiron-services.ch/</services/ki-beratung>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': 'Datenanalyse'}, page_content='### Datenanalyse\nErkennung von Muster, Beziehungen und Prognosen\n[![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)](https://www.chiron-services.ch/</services/datenanalyse>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': 'Prozess-automatisierung'}, page_content='### Prozess-automatisierung\nReduktion manueller Arbeit\n[![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)](https://www.chiron-services.ch/</services/prozessautomatisierung>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': 'Unsere Kernkompetenzen', 'Header 3': 'Software-entwicklung'}, page_content='### Software-entwicklung\nDigitale Lösungen nach Mass\n[![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)](https://www.chiron-services.ch/</services/softwareentwicklung>)\nCHIRON SERVICES'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': '«Just do it. (once)»'}, page_content='## «Just do it. (once)»\nChiron Services unterstützt Sie bei Ihrer digitalen Transformation. Unser Fokus liegt dabei auf der Prozessautomatisierung, die darauf abzielt, manuelle Aufgaben durch den Einsatz von Software zu minimieren.\n[Services](https://www.chiron-services.ch/</services>)\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d7854fe8f81403d34094_HG-2-02%201.png)\nFolge uns'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': '«Just do it. (once)»'}, page_content="Folge uns\n[![LinkedIn Icon](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d4c2095be884047cfb69_linked-in.svg)](https://www.chiron-services.ch/<https:/www.linkedin.com/company/chironservices/?originalSubdomain=ch>)\nKontakt\n[info@chiron-services.ch](https://www.chiron-services.ch/<javascript:linkTo_UnCryptMailto\\('nbjmup;jogpAdijspo.tfswjdft/di'\\);>)\n[Tel. +41 79 944 90 90](https://www.chiron-services.ch/<tel:+41799449090>)\nQuick Links"),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': '«Just do it. (once)»'}, page_content='Quick Links\n[Karriere](https://www.chiron-services.ch/</karriere>)[Impressum](https://www.chiron-services.ch/</impressum>)[Datenschutz](https://www.chiron-services.ch/</datenschutz>)\n[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/</>)\nChiron Services GmbH, Starenstrasse 33, 4059 Basel, Schweiz | ©2023 Chiron Services GmbH. All Rights Reserved.'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': '«Just do it. (once)»'}, page_content='[Close Cookie Popup](https://www.chiron-services.ch/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu. Cookies werden genutzt um die Navigation auf der Website zu verbessern und die Nutzung der Website zu analysieren.[Mehr Infos](https://www.chiron-services.ch/</datenschutz>)\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/<#>)[Konfigurieren](https://www.chiron-services.ch/<#>)'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': '«Just do it. (once)»'}, page_content='[Close Cookie Preference Manager](https://www.chiron-services.ch/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu, um die Navigation auf der Website zu verbessern, die Nutzung der Website zu analysieren und unsere Marketingaktivitäten zu unterstützen. [Mehr Infos](https://www.chiron-services.ch/</datenschutz>)\nNotwendig (immer aktiv)\nCookies, die erforderlich sind, um grundlegende Funktionen der Website zu ermöglichen.'),
#  Document(metadata={'Header 1': 'Unlocking the Value of Data', 'Header 2': '«Just do it. (once)»'}, page_content='Analytics\nWir verwenden Google Analytics. Durch die Aktivierung dieser Funktion werden Cookies gesetzt, die uns helfen zu verstehen, wie diese Website funktioniert, wie Besucher mit der Website interagieren und ob es technische Probleme gibt.\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/<#>)[Einstellungen speichern](https://www.chiron-services.ch/<#>)'),
#  Document(metadata={}, page_content='[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/</>)[Über uns](https://www.chiron-services.ch/</ueber-uns>)[Services](https://www.chiron-services.ch/</services>)[Produkte](https://www.chiron-services.ch/</produkte>)[NEWS](https://www.chiron-services.ch/</news>)'),
#  Document(metadata={}, page_content='[DE](https://www.chiron-services.ch/</services>)[|](https://www.chiron-services.ch/<#>)[EN](https://www.chiron-services.ch/</en/services>)'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='# «Think big, start small!»\nChiron Services bietet eine innovative Herangehensweise an, um Ihre Geschäftsprozesse zu optimieren und Ihre Visionen zu verwirklichen. Wir glauben daran, dass man gross denken sollte, um Grosses zu erreichen, aber auch kleine Schritte unternehmen sollte, um dorthin zu gelangen.Unser "Think Big, Start Small"-Ansatz ermöglicht es Ihnen, schnell und effektiv Ergebnisse zu erzielen. Wir konzentrieren uns darauf, kleine Schritte zu unternehmen, um grosse Fortschritte zu erzielen.'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='![Ablauf](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435e4f3aa949936b4cdceca_chiron_Ablauf_SmallBig4%201.png)'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='Unser Angebot umfasst eine breite Palette von Dienstleistungen, von der Beratung und Planung bis zur Implementierung und Schulung. Wir sind bestrebt, unseren Kunden die bestmögliche Lösung zu bieten, die auf ihren spezifischen Bedürfnissen basiert. Wir arbeiten mit modernster Technologie und bewährten Methoden, um Ihnen zu helfen, Ihre Ziele effektiv zu erreichen.Think Big, Start Small - wir sind bereit, Ihnen zu helfen!'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='[![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/64353ed27f90895ae5a7b311_iconos%20chiron%20_%20NEGATIVOS-08.png)DatenerhebungAutomatisches Sammeln von Daten](https://www.chiron-services.ch/</services/datenerhebung>)[![Datenextraktion](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85120b4d2a564a962b_iconos%20chiron%20_%20negativos-26.png)DatenextraktionUmwandlung von unstrukturierten Daten in'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='Daten in strukturierte](https://www.chiron-services.ch/</services/datenextraktion>)[![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435aed4120b4d68534a98a9_iconos%20chiron%20_%20NEGATIVOS-24.png)Daten-aufbereitungStandardisierung und'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='und Organisation](https://www.chiron-services.ch/</services/datenaufbereitung>)[![Datenmanagment](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae857261641e77e23dd8_iconos%20chiron%20_%20NEGATIVOS-21.png)Daten-managementSpeicherung und Zugriff auf Daten](https://www.chiron-services.ch/</services/datenmanagement>)[![Datenanalyse](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae854d9b1140d0017178_iconos%20chiron%20_%20NEGATIVOS-05.png)DatenanalyseErkennung von Muster,'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='von Muster, Beziehungen und Prognosen](https://www.chiron-services.ch/</services/datenanalyse>)[![Prozessautomatisierung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d31a6a6757e3d1b2_iconos%20chiron%20_%20NEGATIVOS-11.png)Prozess-automatisierungReduktion manueller'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='manueller Arbeit](https://www.chiron-services.ch/</services/prozessautomatisierung>)[![Softwareentwicklung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85d807831d41e31232_iconos%20chiron%20_%20NEGATIVOS-01.png)Software-entwicklungDigitale Lösungen nach Mass](https://www.chiron-services.ch/</services/softwareentwicklung>)[![KI Beratung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435ae85f18c12d8480b4380_iconos%20chiron%20_%20NEGATIVOS-18.png)KI BeratungEinsatz'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='BeratungEinsatz künstlicher Intelligenz für Ihr Unternehmen](https://www.chiron-services.ch/</services/ki-beratung>)'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content="![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d7854fe8f81403d34094_HG-2-02%201.png)\nFolge uns\n[![LinkedIn Icon](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d4c2095be884047cfb69_linked-in.svg)](https://www.chiron-services.ch/<https:/www.linkedin.com/company/chironservices/?originalSubdomain=ch>)\nKontakt\n[info@chiron-services.ch](https://www.chiron-services.ch/<javascript:linkTo_UnCryptMailto\\('nbjmup;jogpAdijspo.tfswjdft/di'\\);>)"),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='[Tel. +41 79 944 90 90](https://www.chiron-services.ch/<tel:+41799449090>)\nQuick Links\n[Karriere](https://www.chiron-services.ch/</karriere>)[Impressum](https://www.chiron-services.ch/</impressum>)[Datenschutz](https://www.chiron-services.ch/</datenschutz>)\n[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/</>)'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='Chiron Services GmbH, Starenstrasse 33, 4059 Basel, Schweiz | ©2023 Chiron Services GmbH. All Rights Reserved.\n[Close Cookie Popup](https://www.chiron-services.ch/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu. Cookies werden genutzt um die Navigation auf der Website zu verbessern und die Nutzung der Website zu analysieren.[Mehr Infos](https://www.chiron-services.ch/</datenschutz>)'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='[Alle Cookies akzeptieren](https://www.chiron-services.ch/<#>)[Konfigurieren](https://www.chiron-services.ch/<#>)\n[Close Cookie Preference Manager](https://www.chiron-services.ch/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu, um die Navigation auf der Website zu verbessern, die Nutzung der Website zu analysieren und unsere Marketingaktivitäten zu unterstützen. [Mehr Infos](https://www.chiron-services.ch/</datenschutz>)'),
#  Document(metadata={'Header 1': '«Think big, start small!»'}, page_content='Notwendig (immer aktiv)\nCookies, die erforderlich sind, um grundlegende Funktionen der Website zu ermöglichen.\nAnalytics\nWir verwenden Google Analytics. Durch die Aktivierung dieser Funktion werden Cookies gesetzt, die uns helfen zu verstehen, wie diese Website funktioniert, wie Besucher mit der Website interagieren und ob es technische Probleme gibt.\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/<#>)[Einstellungen speichern](https://www.chiron-services.ch/<#>)'),
#  Document(metadata={}, page_content='[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/services/</>)[Über uns](https://www.chiron-services.ch/services/</ueber-uns>)[Services](https://www.chiron-services.ch/services/</services>)[Produkte](https://www.chiron-services.ch/services/</produkte>)[NEWS](https://www.chiron-services.ch/services/</news>)'),
#  Document(metadata={}, page_content='[DE](https://www.chiron-services.ch/services/</services/datenaufbereitung>)[|](https://www.chiron-services.ch/services/<#>)[EN](https://www.chiron-services.ch/services/</en/services/data-preparation>)'),
#  Document(metadata={'Header 1': 'Datenaufbereitung'}, page_content='# Datenaufbereitung\n![Datenaufbereitung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435edb01f0ef4eeacd428be_iconos%20chiron%20_%20NEGATIVOS-24.png)'),
#  Document(metadata={'Header 1': 'Datenaufbereitung'}, page_content='Oft sind Daten unstrukturiert und nicht sauber, was bedeutet, dass sie in ihrer rohen Form nicht weiterverwendet werden können. Bei Chiron Services bieten wir professionelle Dienstleistungen zur Datenbereinigung und -standardisierung an, um sicherzustellen, dass Ihre Daten sauber und verwertbar sind.Wir können Ihnen helfen, Daten aus verschiedenen Quellen zu standardisieren und zusammenzuführen, um einheitliche Datensätze zu erstellen, die eine bessere Analyse und Verarbeitung ermöglichen.'),
#  Document(metadata={'Header 1': 'Datenaufbereitung'}, page_content='![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452cdaddbd0c531abd4d757_struktur.png)'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Strukturierung'}, page_content='## Strukturierung\nDaten organisieren\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452cdadf3522742443a78ba_standard.png)'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Standardisierung'}, page_content='## Standardisierung\nVereinheitlichung von Daten\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452cdadc5a0984dd547f937_bereinigung.png)'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Bereinigung'}, page_content='## Bereinigung\nAussortieren von nicht benötigten Daten'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Use Case - Nationaler Datenstream', 'Header 3': 'Projektname: UniDB'}, page_content='## Use Case - Nationaler Datenstream  \n### Projektname: UniDB'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Use Case - Nationaler Datenstream', 'Header 3': 'Projektname: UniDB'}, page_content='Für drei Universitätsspitälern haben wir das Projekt UniDB durchgeführt, eine Machbarkeitsstudie für die Erstellung einer gemeinsamen, verlinkten Datenbank. Wir begannen mit der Analyse der verschiedenen Datenbanken innerhalb der einzelnen Universitätsspitäler und versuchten, diese miteinander zu verknüpfen. Im Anschluss daran haben wir uns auf die Zusammenführung der Datenbanken der drei Universitätsspitäler zu einer gemeinsamen Datenbank konzentriert. Während der Durchführung arbeiteten wir eng mit den'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Use Case - Nationaler Datenstream', 'Header 3': 'Projektname: UniDB'}, page_content='wir eng mit den IT-Abteilungen der beteiligten Universitätsspitäler zusammen, wobei wir uns vor Ort befanden und unter strengen NDA-Verträgen arbeiteten.Die Datenbanken enthielten äusserst umfangreiche und sensible Informationen, was zu sehr strikten Geheimhaltungsregeln führte. Unsere Arbeit erforderte daher ein hohes Mass an Professionalität und Genauigkeit, um sicherzustellen, dass alle Daten sorgfältig behandelt wurden und die Anforderungen unserer Kunden erfüllt wurden. Wir haben bei der Umsetzung'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Use Case - Nationaler Datenstream', 'Header 3': 'Projektname: UniDB'}, page_content='haben bei der Umsetzung auch die Anonymisierung der Beobachtungen im Konzept berücksichtigt, um sicherzustellen, dass alle Datenschutzbestimmungen eingehalten wurden.Unser von uns entwickeltes Konzept bot klare Anleitungen und Methoden, um sicherzustellen, dass die Daten für eine effektive Analyse und Verarbeitung bereit waren. Das Konzept ermöglichte somit eine erfolgreiche Verlinkung der Datenbanken und bildete eine solide Grundlage für das weitere Vorgehen.'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Use Case - Nationaler Datenstream', 'Header 3': 'Auf einen Blick'}, page_content='### Auf einen Blick\n![Chart](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/643727cd21cf93303d5cbac2_chart.svg)\nZentralisierung von Datenbanken\n![Graph](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/643727ce3caef9cd7c7754e0_graph.svg)\nStandortunabhängige Analyse von Daten\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452c9fd20baeabd8db4b6d3_up.png)\nGrundlage zur Nutzung von BigData Analytics'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Use Case - Nationaler Datenstream', 'Header 3': 'Auf einen Blick'}, page_content='![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/646b1ea45895e07b93b1dba5_Chiron_services_frederik_wetzel.webp)'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Kontakt'}, page_content="## Kontakt\nStehen Sie vor ähnlichen Herausforderungen oder haben Sie bereits konkretere Ideen? Melden Sie sich für ein unverbindliches Erstgespräch!**Frederik Wetzel**\n[wetzel@chiron-services.ch](https://www.chiron-services.ch/services/<javascript:linkTo_UnCryptMailto\\('nbjmup;xfu{fmAdijspo.tfswjdft/di'\\);>)\n079 944 90 90\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d7854fe8f81403d34094_HG-2-02%201.png)\nFolge uns"),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Kontakt'}, page_content="Folge uns\n[![LinkedIn Icon](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d4c2095be884047cfb69_linked-in.svg)](https://www.chiron-services.ch/services/<https:/www.linkedin.com/company/chironservices/?originalSubdomain=ch>)\nKontakt\n[info@chiron-services.ch](https://www.chiron-services.ch/services/<javascript:linkTo_UnCryptMailto\\('nbjmup;jogpAdijspo.tfswjdft/di'\\);>)\n[Tel. +41 79 944 90 90](https://www.chiron-services.ch/services/<tel:+41799449090>)\nQuick Links"),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Kontakt'}, page_content='Quick Links\n[Karriere](https://www.chiron-services.ch/services/</karriere>)[Impressum](https://www.chiron-services.ch/services/</impressum>)[Datenschutz](https://www.chiron-services.ch/services/</datenschutz>)\n[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/services/</>)\nChiron Services GmbH, Starenstrasse 33, 4059 Basel, Schweiz | ©2023 Chiron Services GmbH. All Rights Reserved.'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Kontakt'}, page_content='[Close Cookie Popup](https://www.chiron-services.ch/services/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu. Cookies werden genutzt um die Navigation auf der Website zu verbessern und die Nutzung der Website zu analysieren.[Mehr Infos](https://www.chiron-services.ch/services/</datenschutz>)\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/services/<#>)[Konfigurieren](https://www.chiron-services.ch/services/<#>)'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Kontakt'}, page_content='[Close Cookie Preference Manager](https://www.chiron-services.ch/services/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu, um die Navigation auf der Website zu verbessern, die Nutzung der Website zu analysieren und unsere Marketingaktivitäten zu unterstützen. [Mehr Infos](https://www.chiron-services.ch/services/</datenschutz>)\nNotwendig (immer aktiv)'),
#  Document(metadata={'Header 1': 'Datenaufbereitung', 'Header 2': 'Kontakt'}, page_content='Notwendig (immer aktiv)\nCookies, die erforderlich sind, um grundlegende Funktionen der Website zu ermöglichen.\nAnalytics\nWir verwenden Google Analytics. Durch die Aktivierung dieser Funktion werden Cookies gesetzt, die uns helfen zu verstehen, wie diese Website funktioniert, wie Besucher mit der Website interagieren und ob es technische Probleme gibt.\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/services/<#>)[Einstellungen speichern](https://www.chiron-services.ch/services/<#>)'),
#  Document(metadata={}, page_content='[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/services/</>)[Über uns](https://www.chiron-services.ch/services/</ueber-uns>)[Services](https://www.chiron-services.ch/services/</services>)[Produkte](https://www.chiron-services.ch/services/</produkte>)[NEWS](https://www.chiron-services.ch/services/</news>)'),
#  Document(metadata={}, page_content='[DE](https://www.chiron-services.ch/services/</services/datenerhebung>)[|](https://www.chiron-services.ch/services/<#>)[EN](https://www.chiron-services.ch/services/</en/services/data-collection>)'),
#  Document(metadata={'Header 1': 'Datenerhebung'}, page_content='# Datenerhebung\n![Datenerhebung](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/643c6b9144135a5c2149e2f9_iconos%20chiron%20_%20negativos-26.png)'),
#  Document(metadata={'Header 1': 'Datenerhebung'}, page_content='Die Fähigkeit, Daten effektiv zu sammeln, ist der Schlüssel zur Optimierung von Geschäftsprozessen und bildet die Grundlage von Datenanalysen.Wir können Ihnen bei der Sammlung von Daten aus verschiedenen Quellen helfen, einschliesslich Websites, sozialen Medien, Online-Marktplätzen und internen Quellen. Mit unserem Team von erfahrenen Datenwissenschaftlern und Softwareentwicklern bieten wir Ihnen massgeschneiderte Lösungen für Ihre spezifischen Anforderungen.'),
#  Document(metadata={'Header 1': 'Datenerhebung'}, page_content='![A hand clicking a button on a globe for data collection.](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452ca757004376f2acd6537_webscraping.png)'),
#  Document(metadata={'Header 1': 'Datenerhebung', 'Header 2': 'Web scraping'}, page_content='## Web scraping\nAutomatische Datenerhebung aus dem Internet\n![A hand clicking a button on a globe for data collection.](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452ca752fd8b18c1e786e8f_interne.png)'),
#  Document(metadata={'Header 1': 'Datenerhebung', 'Header 2': 'Interne Datenerhebung'}, page_content='## Interne Datenerhebung\nErhebung aus internen Prozessen und Daten\n![A hand clicking a button on a globe for data collection.](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452ca75e2366f27200a49ec_social-media.png)'),
#  Document(metadata={'Header 1': 'Datenerhebung', 'Header 2': 'Social Media scraping'}, page_content='## Social Media scraping\nDatenerhebung aus Social Media'),
#  Document(metadata={'Header 1': 'Datenerhebung', 'Header 2': 'Use Case - Automatisierte Fahrzeugbewertung', 'Header 3': 'Automatisierte Fahrzeugbewertung dank Scraping von Autopreisen'}, page_content='## Use Case - Automatisierte Fahrzeugbewertung  \n### Automatisierte Fahrzeugbewertung dank Scraping von Autopreisen'),
#  Document(metadata={'Header 1': 'Datenerhebung', 'Header 2': 'Use Case - Automatisierte Fahrzeugbewertung', 'Header 3': 'Automatisierte Fahrzeugbewertung dank Scraping von Autopreisen'}, page_content='Ein Projekt, welches wir erfolgreich umgesetzt haben, war das Scrapen von Autopreisen und den dazugehörigen Fahrzeuginformationen von verschiedenen Auto-Handelsplattformen, um unseren Kunden bei der Entwicklung eines automatisierten Fahrzeugbewertungsverfahrens zu unterstützen. Dank unseres Systems kann der Kunde stets einen der gewinnbringendsten Preise auf dem Markt erzielen.Der Kunde konnte während des Projekts seine Effizienz steigern und seine Kosten reduzieren, indem er auf unsere Dienstleistungen'),
#  Document(metadata={'Header 1': 'Datenerhebung', 'Header 2': 'Use Case - Automatisierte Fahrzeugbewertung', 'Header 3': 'Automatisierte Fahrzeugbewertung dank Scraping von Autopreisen'}, page_content='unsere Dienstleistungen zurückgriff. Unser automatisiertes System lädt täglich mehr als eine halbe Million Datenpunkte herunter und verarbeitet sie vollautomatisch, um sicherzustellen, dass der Kunde immer auf dem neuesten Stand ist. Ohne unser System wäre eine manuelle Verarbeitung dieser Daten nicht nur zeitaufwendig und ressourcenintensiv gewesen, sondern hätte auch die Genauigkeit und Aktualität der Ergebnisse beeinträchtigt.Unser Kunde konnte stets seine Experten-Meinung in den Prozess integrieren, um'),
#  Document(metadata={'Header 1': 'Datenerhebung', 'Header 2': 'Use Case - Automatisierte Fahrzeugbewertung', 'Header 3': 'Automatisierte Fahrzeugbewertung dank Scraping von Autopreisen'}, page_content='Prozess integrieren, um sicherzustellen, dass das Endprodukt seinen Anforderungen entspricht. Dank unserer weiteren Dienstleistungen konnte der Kunde bereits während des Projekts seine Effizienz steigern und seine Kosten reduzieren. Wir sind stolz darauf, unseren Kunden dabei geholfen zu haben, bessere Geschäftsentscheidungen zu treffen, indem wir sicherstellen konnten, dass er stets die relevantesten und aktuellsten Daten zur Verfügung hat.'),
#  Document(metadata={'Header 1': 'Datenerhebung', 'Header 2': 'Use Case - Automatisierte Fahrzeugbewertung', 'Header 3': 'Auf einen Blick'}, page_content='### Auf einen Blick\n![Chart](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/643727cd21cf93303d5cbac2_chart.svg)\nVerbesserte Planung\n![Graph](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/643727ce3caef9cd7c7754e0_graph.svg)\nSchonung Ressourcen\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452c9fd20baeabd8db4b6d3_up.png)\nErhöhte Effizienz\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/646b1ea45895e07b93b1dba5_Chiron_services_frederik_wetzel.webp)'),
# ...
#  Document(metadata={'Header 1': 'DataDJ'}, page_content='System entwickelt, das Forschern und Institutionen dabei hilft, Daten einfacher auszuwählen und darauf zuzugreifen als je zuvor. DataDJ ist ein dezentrales Netzwerk, das es Datenbankverwaltern und -eigentümern ermöglicht, ihre Daten über das Netzwerk zugänglich zu machen. Eine benutzerfreundliche Oberfläche, ermöglicht es Nutzern, nach Daten zu suchen und sie ganz einfach anzufordern – ähnlich wie beim Einkauf in Online-Shops. Am Ende erhält der Nutzer eine E-Mail mit einem Download-Link, um die'),
#  Document(metadata={'Header 1': 'DataDJ'}, page_content='Download-Link, um die angeforderten Daten herunterzuladen.Aktuell hat der DataDJ noch Prototypen Status, jedoch wird er weiterentwickelt und neue Funktionalitäten hinzugefügt. Bei Fragen zum DataDJ, seiner Nutzung oder Interesse bei der Entwicklung mitzuwirken nehmen Sie Kontakt zu uns auf und wir helfen Ihnen gerne weiter.'),
#  Document(metadata={'Header 1': 'DataDJ'}, page_content='[zurück zu den Produkten](https://www.chiron-services.ch/produkte/</produkte>)\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452c4310285303dcbe7f891_magnus-wuttke.webp)'),
#  Document(metadata={'Header 1': 'DataDJ', 'Header 2': 'Kontakt'}, page_content="## Kontakt\nMöchten Sie gerne mehr über DataDJ erfahren? Kontaktieren Sie unseren Productowner:**Magnus Wuttke**\n[wuttke@chiron-services.ch](https://www.chiron-services.ch/produkte/<javascript:linkTo_UnCryptMailto\\('nbjmup;xvuulfAdijspo.tfswjdft/di'\\);>)\n078 264 34 97\n![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d7854fe8f81403d34094_HG-2-02%201.png)\nFolge uns"),
#  Document(metadata={'Header 1': 'DataDJ', 'Header 2': 'Kontakt'}, page_content="Folge uns\n[![LinkedIn Icon](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d4c2095be884047cfb69_linked-in.svg)](https://www.chiron-services.ch/produkte/<https:/www.linkedin.com/company/chironservices/?originalSubdomain=ch>)\nKontakt\n[info@chiron-services.ch](https://www.chiron-services.ch/produkte/<javascript:linkTo_UnCryptMailto\\('nbjmup;jogpAdijspo.tfswjdft/di'\\);>)\n[Tel. +41 79 944 90 90](https://www.chiron-services.ch/produkte/<tel:+41799449090>)\nQuick Links"),
#  Document(metadata={'Header 1': 'DataDJ', 'Header 2': 'Kontakt'}, page_content='Quick Links\n[Karriere](https://www.chiron-services.ch/produkte/</karriere>)[Impressum](https://www.chiron-services.ch/produkte/</impressum>)[Datenschutz](https://www.chiron-services.ch/produkte/</datenschutz>)\n[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/produkte/</>)\nChiron Services GmbH, Starenstrasse 33, 4059 Basel, Schweiz | ©2023 Chiron Services GmbH. All Rights Reserved.'),
#  Document(metadata={'Header 1': 'DataDJ', 'Header 2': 'Kontakt'}, page_content='[Close Cookie Popup](https://www.chiron-services.ch/produkte/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu. Cookies werden genutzt um die Navigation auf der Website zu verbessern und die Nutzung der Website zu analysieren.[Mehr Infos](https://www.chiron-services.ch/produkte/</datenschutz>)\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/produkte/<#>)[Konfigurieren](https://www.chiron-services.ch/produkte/<#>)'),
#  Document(metadata={'Header 1': 'DataDJ', 'Header 2': 'Kontakt'}, page_content='[Close Cookie Preference Manager](https://www.chiron-services.ch/produkte/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu, um die Navigation auf der Website zu verbessern, die Nutzung der Website zu analysieren und unsere Marketingaktivitäten zu unterstützen. [Mehr Infos](https://www.chiron-services.ch/produkte/</datenschutz>)\nNotwendig (immer aktiv)'),
#  Document(metadata={'Header 1': 'DataDJ', 'Header 2': 'Kontakt'}, page_content='Notwendig (immer aktiv)\nCookies, die erforderlich sind, um grundlegende Funktionen der Website zu ermöglichen.\nAnalytics\nWir verwenden Google Analytics. Durch die Aktivierung dieser Funktion werden Cookies gesetzt, die uns helfen zu verstehen, wie diese Website funktioniert, wie Besucher mit der Website interagieren und ob es technische Probleme gibt.\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/produkte/<#>)[Einstellungen speichern](https://www.chiron-services.ch/produkte/<#>)'),
#  Document(metadata={}, page_content='[Close Cookie Popup](https://www.chiron-services.ch/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu. Cookies werden genutzt um die Navigation auf der Website zu verbessern und die Nutzung der Website zu analysieren.[Mehr Infos](https://www.chiron-services.ch/</datenschutz>)\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/<#>)[Konfigurieren](https://www.chiron-services.ch/<#>)'),
#  Document(metadata={}, page_content='[Close Cookie Preference Manager](https://www.chiron-services.ch/<#>)\nCookie Einstellungen\nWenn Sie auf "Alle Cookies akzeptieren" klicken, stimmen Sie der Speicherung von Cookies auf Ihrem Gerät zu, um die Navigation auf der Website zu verbessern, die Nutzung der Website zu analysieren und unsere Marketingaktivitäten zu unterstützen. [Mehr Infos](https://www.chiron-services.ch/</datenschutz>)\nNotwendig (immer aktiv)\nCookies, die erforderlich sind, um grundlegende Funktionen der Website zu ermöglichen.'),
#  Document(metadata={}, page_content='Analytics\nWir verwenden Google Analytics. Durch die Aktivierung dieser Funktion werden Cookies gesetzt, die uns helfen zu verstehen, wie diese Website funktioniert, wie Besucher mit der Website interagieren und ob es technische Probleme gibt.\n[Alle Cookies akzeptieren](https://www.chiron-services.ch/<#>)[Einstellungen speichern](https://www.chiron-services.ch/<#>)'),
#  Document(metadata={}, page_content='[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/</>)[Über uns](https://www.chiron-services.ch/</ueber-uns>)[Services](https://www.chiron-services.ch/</services>)[Produkte](https://www.chiron-services.ch/</produkte>)[NEWS](https://www.chiron-services.ch/</news>)\n[**DE**](https://www.chiron-services.ch/</news>)[|](https://www.chiron-services.ch/<#>)[EN](https://www.chiron-services.ch/</en/news>)'),
#  Document(metadata={}, page_content='![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6452d786f288fe89944d79e5_ueber.webp)'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen'}, page_content='# Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen'}, page_content='Im heutigen digitalen Zeitalter befinden sich Unternehmen auf der ganzen Welt in einem Wettlauf um die Nutzung der unglaublichen Möglichkeiten der künstlichen Intelligenz (KI), um der Konkurrenz einen Schritt voraus zu sein. Als führendes Startup für Datenwissenschaft und Softwareentwicklung sind wir stolz darauf, unsere innovativen KI-Lösungen vorzustellen, die Unternehmen dabei helfen, in dieser dynamischen Landschaft erfolgreich zu sein. Willkommen im Blog-Bereich unserer neu gestarteten Website, in dem'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen'}, page_content='Website, in dem wir spannende Neuigkeiten, Updates und Einblicke in unsere KI-gesteuerten Lösungen geben werden.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Der Vorteil von KI:'}, page_content='## Der Vorteil von KI:\nKünstliche Intelligenz hat die Art und Weise, wie Unternehmen arbeiten, neu definiert und neue Möglichkeiten für Wachstum und Rationalisierung von Prozessen geschaffen. Durch die Integration von KI-Technologien in Ihre Abläufe können Sie profitieren von:\n* **Verbesserte Entscheidungsfindung:** KI-gestützte Erkenntnisse ermöglichen es Unternehmen, datengestützte Entscheidungen zu treffen, die zu besseren Ergebnissen und effizienteren Prozessen führen.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Der Vorteil von KI:'}, page_content='* **Bessere Kundenerfahrungen:** KI-gestützte Tools und Dienste können die Interaktion mit Kunden personalisieren und so für ein zufriedenstellendes und ansprechendes Erlebnis sorgen.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Der Vorteil von KI:'}, page_content='* **Gesteigerte Produktivität:** Durch die KI-gestützte Automatisierung sich wiederholender Aufgaben gewinnen die Mitarbeiter wertvolle Zeit, um sich auf kritischere, strategische Aufgaben zu konzentrieren. Durch die KI-gestützte Automatisierung sich wiederholender Aufgaben gewinnen die Mitarbeiter wertvolle Zeit, um sich auf kritischere, strategische Aufgaben zu konzentrieren.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Der Vorteil von KI:'}, page_content='* **Verbessertes Risikomanagement:** KI kann potenzielle Risiken vorhersagen und entschärfen und so Unternehmen helfen, ihre Vermögenswerte zu schützen und einen Wettbewerbsvorteil zu wahren.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Unsere Lösungen:'}, page_content='## Unsere Lösungen:\nWir bieten eine Reihe von KI-gestützten Data-Science- und Software-Lösungen, die auf die individuellen Bedürfnisse Ihres Unternehmens zugeschnitten sind.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Unsere Dienstleistungen umfassen:'}, page_content='## Unsere Dienstleistungen umfassen:\n* **Datenanalyse und -visualisierung:** Erschliessen Sie das verborgene Potenzial Ihrer Daten mit unseren fortschrittlichen Datenanalyse- und Visualisierungstools, die komplexe Datensätze in umsetzbare Erkenntnisse verwandeln.\n* **Lösungen für maschinelles Lernen:** Implementieren Sie leistungsstarke Machine-Learning-Modelle, um zukünftige Trends vorherzusagen, die Entscheidungsfindung zu verbessern und Ihre Geschäftsprozesse zu optimieren.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Unsere Dienstleistungen umfassen:'}, page_content='* **Verarbeitung natürlicher Sprache (NLP):** Nutzen Sie die Möglichkeiten von NLP, um menschliche Sprache zu analysieren und zu verstehen und so einen effizienteren Kundenservice, Stimmungsanalysen und die Erstellung von Inhalten zu ermöglichen.\n* **KI-gesteuerte Automatisierung:** Steigern Sie Ihre betriebliche Effizienz mit unseren KI-gestützten Automatisierungslösungen, die sich wiederholende Aufgaben rationalisieren, die Produktivität steigern und Kosten senken.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Warum Chiron Services:'}, page_content='## Warum Chiron Services:\nWenn Sie eine Partnerschaft mit unserem Startup eingehen, profitieren Sie von:\n* **Fachwissen:** Unser Team besteht aus hochqualifizierten Datenwissenschaftlern, Software-Ingenieuren und KI-Experten, die bereit sind, erstklassige Lösungen zu liefern, die auf Ihre Geschäftsanforderungen zugeschnitten sind.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Warum Chiron Services:'}, page_content='* **Kundenorientierter Ansatz:** Wir legen Wert darauf, Ihre einzigartigen geschäftlichen Herausforderungen und Ziele zu verstehen, um sicherzustellen, dass unsere KI-gestützten Lösungen mit Ihren strategischen Zielen übereinstimmen.\n* **Kontinuierliche Innovation:** Wir sind immer auf dem neuesten Stand der KI-Technologien und sorgen dafür, dass Ihr Unternehmen bei der digitalen Transformation an der Spitze bleibt.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Warum Chiron Services:'}, page_content='* **Skalierbare Lösungen:** Wenn Ihr Unternehmen wächst, können unsere KI-gesteuerten Lösungen entsprechend skaliert werden, um einen nahtlosen Übergang und kontinuierlichen Erfolg zu gewährleisten.'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Fangen Sie noch heute an:'}, page_content='## Fangen Sie noch heute an:\nSind Sie bereit, Ihr Unternehmen mit KI-gesteuerten Lösungen zu verändern? Erkunden Sie unsere Website, um unser Angebot an Data-Science- und Software-Services kennenzulernen, oder kontaktieren Sie unser Expertenteam für ein persönliches Beratungsgespräch. Wir helfen Ihnen, das wahre Potenzial der künstlichen Intelligenz zu erschliessen und Ihr Unternehmen zu neuen Höhen zu führen.\n[zurück zu den News](https://www.chiron-services.ch/</news>)'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Fangen Sie noch heute an:'}, page_content="![](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d7854fe8f81403d34094_HG-2-02%201.png)\nFolge uns\n[![LinkedIn Icon](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d4c2095be884047cfb69_linked-in.svg)](https://www.chiron-services.ch/<https:/www.linkedin.com/company/chironservices/?originalSubdomain=ch>)\nKontakt\n[info@chiron-services.ch](https://www.chiron-services.ch/<javascript:linkTo_UnCryptMailto\\('nbjmup;jogpAdijspo.tfswjdft/di'\\);>)"),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Fangen Sie noch heute an:'}, page_content='[Tel. +41 79 944 90 90](https://www.chiron-services.ch/<tel:+41799449090>)\nQuick Links\n[Karriere](https://www.chiron-services.ch/</karriere>)[Impressum](https://www.chiron-services.ch/</impressum>)[Datenschutz](https://www.chiron-services.ch/</datenschutz>)\n[![Chiron Logo](https://cdn.prod.website-files.com/643483a340aff3191dff2edc/6435d5a6afbf3c4ecdef1f79_Logo_CHIRON-2023-01%201.png)](https://www.chiron-services.ch/</>)'),
#  Document(metadata={'Header 1': 'Unlock the Power of AI: Revolutionieren Sie Ihr Unternehmen mit unseren Data-Science- und Softwarelösungen', 'Header 2': 'Fangen Sie noch heute an:'}, page_content='Chiron Services GmbH, Starenstrasse 33, 4059 Basel, Schweiz | ©2023 Chiron Services GmbH. All Rights Reserved.')]

# %%
def average_pool(last_hidden_states: Tensor,
                 attention_mask: Tensor) -> Tensor:
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

def get_detailed_instruct(task_description: str, query: str) -> str:
    return f'Instruct: {task_description}\nQuery: {query}'

# Each query must come with a one-sentence instruction that describes the task
task = 'Given a web search query, retrieve relevant passages that answer the query'
queries = [
    get_detailed_instruct(task, 'how much protein should a female eat'),
    get_detailed_instruct(task, '南瓜的家常做法')
]
# No need to add instruction for retrieval documents
documents = [
    "As a general guideline, the CDC's average requirement of protein for women ages 19 to 70 is 46 grams per day. But, as you can see from this chart, you'll need to increase that if you're expecting or training for a marathon. Check out the chart below to see how much protein you should be eating each day.",
    "1.清炒南瓜丝 原料:嫩南瓜半个 调料:葱、盐、白糖、鸡精 做法: 1、南瓜用刀薄薄的削去表面一层皮,用勺子刮去瓤 2、擦成细丝(没有擦菜板就用刀慢慢切成细丝) 3、锅烧热放油,入葱花煸出香味 4、入南瓜丝快速翻炒一分钟左右,放盐、一点白糖和鸡精调味出锅 2.香葱炒南瓜 原料:南瓜1只 调料:香葱、蒜末、橄榄油、盐 做法: 1、将南瓜去皮,切成片 2、油锅8成热后,将蒜末放入爆香 3、爆香后,将南瓜片放入,翻炒 4、在翻炒的同时,可以不时地往锅里加水,但不要太多 5、放入盐,炒匀 6、南瓜差不多软和绵了之后,就可以关火 7、撒入香葱,即可出锅"
]
input_texts = queries + documents

tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-large-instruct')
model = AutoModel.from_pretrained('intfloat/multilingual-e5-large-instruct')

# Tokenize the input texts
batch_dict = tokenizer(input_texts, max_length=512, padding=True, truncation=True, return_tensors='pt')

outputs = model(**batch_dict)
embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])

# normalize embeddings
embeddings = F.normalize(embeddings, p=2, dim=1)
scores = (embeddings[:2] @ embeddings[2:].T) * 100
print(scores.tolist())

# %%
class InstructEmbeddings:
    def __init__(self):
        pass

def last_token_pool(last_hidden_states: Tensor, attention_mask: Tensor) -> Tensor:
    left_padding = (attention_mask[:, -1].sum() == attention_mask.shape[0])
    if left_padding:
        return last_hidden_states[:, -1]
    else:
        sequence_lengths = attention_mask.sum(dim=1) - 1
        batch_size = last_hidden_states.shape[0]
        return last_hidden_states[torch.arange(batch_size, device=last_hidden_states.device), sequence_lengths]

def get_detailed_instruct(task_description: str, query: str) -> str:
    return f'Instruct: {task_description}\nQuery: {query}'


# Each query must come with a one-sentence instruction that describes the task
task = 'Given a question, retrieve Wikipedia passages that answer the question'
queries = [
    get_detailed_instruct(task, '최초의 원자력 발전소는 무엇인가?'),
    get_detailed_instruct(task, 'Who invented Hangul?')
]
# No need to add instruction for retrieval documents
passages = [
    "현재 사용되는 핵분열 방식을 이용한 전력생산은 1948년 9월 미국 테네시주 오크리지에 설치된 X-10 흑연원자로에서 전구의 불을 밝히는 데 사용되면서 시작되었다. 그리고 1954년 6월에 구소련의 오브닌스크에 건설된 흑연감속 비등경수 압력관형 원자로를 사용한 오브닌스크 원자력 발전소가 시험적으로 전력생산을 시작하였고, 최초의 상업용 원자력 엉더이로를 사용한 영국 셀라필드 원자력 단지에 위치한 콜더 홀(Calder Hall) 원자력 발전소로, 1956년 10월 17일 상업 운전을 시작하였다.",
    "Hangul was personally created and promulgated by the fourth king of the Joseon dynasty, Sejong the Great.[1][2] Sejong's scholarly institute, the Hall of Worthies, is often credited with the work, and at least one of its scholars was heavily involved in its creation, but it appears to have also been a personal project of Sejong."
]

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('Linq-AI-Research/Linq-Embed-Mistral')
model = AutoModel.from_pretrained('Linq-AI-Research/Linq-Embed-Mistral')

max_length = 4096
input_texts = [*queries, *passages]
# Tokenize the input texts
batch_dict = tokenizer(input_texts, max_length=max_length, padding=True, truncation=True, return_tensors="pt")
outputs = model(**batch_dict)
embeddings = last_token_pool(outputs.last_hidden_state, batch_dict['attention_mask'])

# Normalize embeddings
embeddings = F.normalize(embeddings, p=2, dim=1)
scores = (embeddings[:2] @ embeddings[2:].T) * 100
print(scores.tolist())
